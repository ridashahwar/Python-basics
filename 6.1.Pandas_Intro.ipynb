# %% [markdown]
# ###What is pandas-python?
# introduction and installation
#
#
# Pandas is python module that makes data science easy and effective
#
#
# using weather dataset
# Questions?
#
# 1. What was the maximum temperature in newyork in the month of january?
#
# 2. on which days did it rain?
#
# 3. What was the average speed of wind during the month ?

# %% [markdown]
# Weather DataSet

# %%
import pandas as pd

# %%
df = pd.read_csv('nyc_weather.csv');

# %%
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
#head or tail returns firs or last 5 rows
df.head()
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
df.tail()
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 26  1/27/2016           41        22        45                 30.03
# 27  1/28/2016           37        20        51                 29.90
# 28  1/29/2016           36        21        50                 29.58
# 29  1/30/2016           34        16        46                 30.01
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 26               10           7.0               T           3   Rain
# 27               10           5.0               0           1    NaN
# 28               10           8.0               0           4    NaN
# 29               10           7.0               0           0    NaN
# 30               10           5.0               0           0    NaN
#
#     WindDirDegrees
# 26             311
# 27             234
# 28             298
# 29             257
# 30             241

# %%
#to get Max val of col
df['Temperature'].max()
# Out:
# 50

# %%
# To pick rows based on conditions

df[['Temperature','EST']][df['Events'] == 'Rain']
# Out:
#     Temperature        EST
# 8            44   1/9/2016
# 9            50  1/10/2016
# 15           47  1/16/2016
# 26           41  1/27/2016

# %%
df[df['Events'] == 'Rain']
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 15  1/16/2016           47        37        70                 29.52
# 26  1/27/2016           41        22        45                 30.03
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 8                 9           8.0               T           8   Rain
# 9                 4           NaN             1.8           7   Rain
# 15                8           7.0            0.24           7   Rain
# 26               10           7.0               T           3   Rain
#
#     WindDirDegrees
# 8               76
# 9              109
# 15             340
# 26             311

# %%
df['WindSpeedMPH'].mean()
# Out:
# 6.892857142857143

# %% [markdown]
# ### Installation
#
# pip3 install pandas

# %% [markdown]
# Introduction to  Pandas dataframes
#
# Dataframe is main object in pandas. It is used to represent data with rows and columns.
#
# Data frame is a data structure represent the data in tabular or excel spread sheet like data.

# %% [markdown]
# Creating dataframe:

# %%
import pandas as pd
df = pd.read_csv('weather_data.csv');

# %%
#6 rows 4 cols
df.shape
# Out:
# (6, 4)

# %% [markdown]
# ### Slicing

# %%
df[2:5]
# Out:
#         day  temperature  windspeed event
# 2  1/3/2017           28          2  Snow
# 3  1/4/2017           24          7  Snow
# 4  1/5/2017           32          4  Rain

# %%
df.day
#or df['day'] or df.get('day')
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# 3    1/4/2017
# 4    1/5/2017
# 5    1/6/2017
# Name: day, dtype: object

# %% [markdown]
# #### To select multiple cols

# %%
df[['day','temperature']]
# Out:
#         day  temperature
# 0  1/1/2017           32
# 1  1/2/2017           35
# 2  1/3/2017           28
# 3  1/4/2017           24
# 4  1/5/2017           32
# 5  1/6/2017           31

# %%
df['temperature'].max()
# Out:
# 35

# %%
df['temperature'].min()
# Out:
# 24

# %% [markdown]
# ### describe()

# %%
#print max temperature
df['temperature'].describe()
# Out:
# count     6.000000
# mean     30.333333
# std       3.829708
# min      24.000000
# 25%      28.750000
# 50%      31.500000
# 75%      32.000000
# max      35.000000
# Name: temperature, dtype: float64

# %%
#select rows which has maximum temperature
df[df['temperature']==df['temperature'].max()]
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny

# %%
df['day'][df['temperature']==df['temperature'].max()]
# Out:
# 1    1/2/2017
# Name: day, dtype: object

# %% [markdown]
# ### Read and write CSV and XLS files

# %%
import pandas as pd
df = pd.read_csv('weather_data.csv')
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
#write DF to csv
df.to_csv('new.csv')
df.to_csv('new_noIndex.csv',index= False)

# %%
# install: pip3 install openpyxl
#write DF to excel
df.to_excel('new.xlsx', sheet_name = 'weather_data')

# %% [markdown]
# GROUP_BY

# %%
import pandas as pd
df= pd.read_csv('weather_data_cities.csv')
df  #weather by cities
# Out:
#          day      city  temperature  windspeed   event
# 0   1/1/2017  new york           32          6    Rain
# 1   1/2/2017  new york           36          7   Sunny
# 2   1/3/2017  new york           28         12    Snow
# 3   1/4/2017  new york           33          7   Sunny
# 4   1/1/2017    mumbai           90          5   Sunny
# 5   1/2/2017    mumbai           85         12     Fog
# 6   1/3/2017    mumbai           87         15     Fog
# 7   1/4/2017    mumbai           92          5    Rain
# 8   1/1/2017     paris           45         20   Sunny
# 9   1/2/2017     paris           50         13  Cloudy
# 10  1/3/2017     paris           54          8  Cloudy
# 11  1/4/2017     paris           42         10  Cloudy

# %%
g = df.groupby('city')
g

# %%
for city, city_df in g:
    print(city)
    print(city_df)
# Out:
# mumbai
#         day    city  temperature  windspeed  event
# 4  1/1/2017  mumbai           90          5  Sunny
# 5  1/2/2017  mumbai           85         12    Fog
# 6  1/3/2017  mumbai           87         15    Fog
# 7  1/4/2017  mumbai           92          5   Rain
# new york
#         day      city  temperature  windspeed  event
# 0  1/1/2017  new york           32          6   Rain
# 1  1/2/2017  new york           36          7  Sunny
# 2  1/3/2017  new york           28         12   Snow
# 3  1/4/2017  new york           33          7  Sunny
# paris
#          day   city  temperature  windspeed   event
# 8   1/1/2017  paris           45         20   Sunny
# 9   1/2/2017  paris           50         13  Cloudy
# 10  1/3/2017  paris           54          8  Cloudy
# 11  1/4/2017  paris           42         10  Cloudy

# %%
print(g.max())
# Out:
#                day  temperature  windspeed  event
# city
# mumbai    1/4/2017           92         15  Sunny
# new york  1/4/2017           36         12  Sunny
# paris     1/4/2017           54         20  Sunny

# %%
print(g.mean())
# Out:
#           temperature  windspeed
# city
# mumbai          88.50       9.25
# new york        32.25       8.00
# paris           47.75      12.75

# %%
print(g.describe())
# Out:
#          temperature                                                   \
#                count   mean       std   min    25%   50%    75%   max
# city
# mumbai           4.0  88.50  3.109126  85.0  86.50  88.5  90.50  92.0
# new york         4.0  32.25  3.304038  28.0  31.00  32.5  33.75  36.0
# paris            4.0  47.75  5.315073  42.0  44.25  47.5  51.00  54.0
#
#          windspeed
#              count   mean       std  min   25%   50%    75%   max
# city
# mumbai         4.0   9.25  5.057997  5.0  5.00   8.5  12.75  15.0
# new york       4.0   8.00  2.708013  6.0  6.75   7.0   8.25  12.0
# paris          4.0  12.75  5.251984  8.0  9.50  11.5  14.75  20.0

# %% [markdown]
# concatenate data frames

# %%
import pandas as pd
india_weather = pd.DataFrame({
    "city": ["mumbai","delhi","banglore"],
    "temperature": [32,45,30],
    "humidity" : [80,60,78]})
    
india_weather
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78

# %%
us_weather = pd.DataFrame({
    "city" :["new york","chicago","orlando"],
    "temperature":[21,14,35],
    "humidity": [80,60,78]
    })
us_weather
# Out:
#        city  temperature  humidity
# 0  new york           21        80
# 1   chicago           14        60
# 2   orlando           35        78

# %%
#concate two dataframes
df = pd.concat([india_weather,us_weather])
df
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78
# 0  new york           21        80
# 1   chicago           14        60
# 2   orlando           35        78

# %%
#if you want continous index

df= pd.concat([india_weather,us_weather],ignore_index = True)
df
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78
# 3  new york           21        80
# 4   chicago           14        60
# 5   orlando           35        78

# %%
df = pd.concat([india_weather,us_weather],axis = 1)
df
# Out:
#        city  temperature  humidity      city  temperature  humidity
# 0    mumbai           32        80  new york           21        80
# 1     delhi           45        60   chicago           14        60
# 2  banglore           30        78   orlando           35        78

# %% [markdown]
# ### Merge DataFrames

# %%
temperature_df = pd.DataFrame({
    "city": ["mumdai","delhi","banglore","Hyderabad"],
    "temperature": [32,45,30,40]})
temperature_df
# Out:
#         city  temperature
# 0     mumdai           32
# 1      delhi           45
# 2   banglore           30
# 3  Hyderabad           40

# %%
humidity_df= pd.DataFrame({
    "city": ["delhi","mumbai","banglore"], "humidity":[68,65,75]
    })
humidity_df
# Out:
#        city  humidity
# 0     delhi        68
# 1    mumbai        65
# 2  banglore        75

# %%
#merge two dataframes with out explicitly mention index 
df = pd.merge(temperature_df, humidity_df, on = 'city')
df
# Out:
#        city  temperature  humidity
# 0     delhi           45        68
# 1  banglore           30        75

# %%
#outer-join
df = pd.merge(temperature_df, humidity_df, on = 'city', how= 'outer')
df
# Out:
#         city  temperature  humidity
# 0     mumdai         32.0       NaN
# 1      delhi         45.0      68.0
# 2   banglore         30.0      75.0
# 3  Hyderabad         40.0       NaN
# 4     mumbai          NaN      65.0

# %% [markdown]
# ###  Numerical Indexing(.loc vs iloc)

# %%
df = pd.DataFrame [1,2,3,4,5,6,7,8,9,19], index= [49,48,47,46,45,1,2,3,4]
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-fa45e2b3d5d8> in <module>
# ----> 1 df = pd.DataFrame [1,2,3,4,5,6,7,8,9,19], index= [49,48,47,46,45,1,2,3,4]
#       2 df
#
# ValueError: too many values to unpack (expected 2)

# %%
s.loc[:2]

# %%
s.loc[46]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-3bb568ed1a55> in <module>
# ----> 1 s.loc[46]
#
# NameError: name 's' is not defined

# %%
s.iloc[:2]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-5fc8f2f6735c> in <module>
# ----> 1 s.iloc[:2]
#
# NameError: name 's' is not defined
