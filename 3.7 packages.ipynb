# %% [markdown]
# ### Packages
# Packages are a way of structuring Pythons module by using 'dotted module names'.
#
# A directory must contain a file named init.py in order for python to consider it as package.This file can be left empty but we generally place the initailisation code for the package in this file.
#  ![OIP.fv65Vt4E0Y2z3VXkOS5FpwAAAA.jpg](attachment:OIP.fv65Vt4E0Y2z3VXkOS5FpwAAAA.jpg)

# %% [markdown]
# Importing module from a package.
#
# We can import modules from packages using the dot(.) operator.

# %%
import Game.Image.open

# %%
import twitter
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-401aa7b6a498> in <module>
# ----> 1 import twitter
#
# ModuleNotFoundError: No module named 'twitter'
